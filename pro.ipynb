# %%
d={"name":"james","age":23}
# Out:
# {'name': 'james'}
# {'name': 'james', 'age': 23}

# %%
d={"name":"james","age":23}

class Student:
    name="dinga"
    age=23

s=Student()
print(s.name,s.age)
for k,v in d.items():
    setattr(s,k,v)

print(s.name,s.age)
# Out:
# dinga 23
# james 23
